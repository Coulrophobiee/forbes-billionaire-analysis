# %%
from database import Database
import pandas as pd
import sqlite3
from visualizer import Visualizer

# %%
df = pd.read_csv("data/all_billionaires_1997_2024.csv")

visualizer = Visualizer("data/database.db", "table1")
visualizer.visualize_business_industries()
# Out:
# /tmp/ipykernel_14466/2409403959.py:1: DtypeWarning: Columns (0: self_made) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/all_billionaires_1997_2024.csv")

# %%
visualizer.visualize_billionaire_count("year")

# %%
visualizer.visualize_billionaire_count("year")

# %%
visualizer.visualize_age_distribution()

# %%
visualizer.visualize_self_made_distribution()

# %%
visualizer.visualize_age_vs_wealth()
# Out:
# First 10 age values:
# 0    73.0
# 1    69.0
# 2    65.0
# 3     NaN
# 4    59.0
# 5    68.0
# 6    53.0
# 7     NaN
# 8    71.0
# 9    65.0
# Name: age, dtype: float64
# Age data type: float64
#
# First 10 net_worth values:
# 0    2.0 B
# 1    1.8 B
# 2    3.3 B
# 3    1.0 B
# 4    7.1 B
# 5    1.3 B
# 6    2.9 B
# 7    1.0 B
# 8    1.1 B
# 9    1.8 B
# Name: net_worth, dtype: str
# Net worth data type: str
#
# Age unique values sample:
# [73. 69. 65. nan 59.]
# Plotting 0 points
# Age range: nan - nan
# Net worth range: nan - nan

# %%
visualizer.visualize_gender_distribution()

# %%
visualizer.visualize_top_countries()
